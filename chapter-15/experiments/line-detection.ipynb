# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
image = cv2.imread('line_1.jpg')
resized = cv2.resize(image, (320, 240))
gray = cv2.cvtColor(resized, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap="gray")

# %%
row = gray[180].astype(np.int32)
diff = np.diff(row)
plt.plot(diff)

# %%
def plot_image_and_diff(img, diff):
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(img, cmap="gray")
    plt.subplot(1, 2, 2)
    plt.plot(diff)
plot_image_and_diff(gray, diff)

# %%
image = cv2.imread('carpet_line1.jpg')
resized = cv2.resize(image, (320, 240))
gray = cv2.cvtColor(resized, cv2.COLOR_BGR2GRAY)

row = gray[180].astype(np.int32)
diff = np.diff(row)

plot_image_and_diff(gray, diff)

# %%
blurred = cv2.blur(gray, (10, 10), 0)
row = blurred[180].astype(np.int32)
diff = np.diff(row)
plot_image_and_diff(blurred, diff)

# %%
max_d = np.amax(diff)
min_d = np.amin(diff)
highest = np.where(diff == max_d)[0][0]
lowest = np.where(diff == min_d)[0][0]
plt.plot(diff)
plt.plot([lowest, lowest], [max_d, min_d], "g--")
plt.plot([highest, highest], [max_d, min_d], "g--")

middle = (highest + lowest) / 2
# plt.plot([middle, middle], [max_d, min_d], "r-")

# %%
cv2.line(resized, (int(middle), 0), (int(middle), 240), (255, 0, 0))
cv2.line(resized, (0, 180), (320, 180), (0, 255, 0))
plt.imshow(resized)

# %%
def plot_diffs(image_name):
    image = cv2.imread(image_name)
    resized = cv2.resize(image, (320, 240))
    gray = cv2.cvtColor(resized, cv2.COLOR_BGR2GRAY)
    blurred = cv2.blur(gray, (10, 10), 0)
    row = blurred[180].astype(np.int32)
    diff = np.diff(row)
    plot_image_and_diff(gray, diff)

    max_d = np.amax(diff)
    min_d = np.amin(diff)
    highest = np.where(diff == max_d)[0][0]
    lowest = np.where(diff == min_d)[0][0]

    if max_d < 5 or min_d > -5:
        print("No line")
        return

    middle = (highest + lowest) / 2
    
    plt.plot([lowest, lowest], [max_d, min_d], "g--")
    plt.plot([highest, highest], [max_d, min_d], "g--")
    plt.plot([middle, middle], [max_d, min_d], "r-")
plot_diffs("line_1.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 24
#      22     plt.plot([highest, highest], [max_d, min_d], "g--")
#      23     plt.plot([middle, middle], [max_d, min_d], "r-")
# ---> 24 plot_diffs("line_1.jpg")
#
# Cell In[1], line 2, in plot_diffs(image_name)
#       1 def plot_diffs(image_name):
# ----> 2     image = cv2.imread(image_name)
#       3     resized = cv2.resize(image, (320, 240))
#       4     gray = cv2.cvtColor(resized, cv2.COLOR_BGR2GRAY)
#
# NameError: name 'cv2' is not defined

# %%
plot_diffs("empty_carpet.jpg")
# Out:
# No line

# %%
plot_diffs("empty_gray.jpg")
# Out:
# No line

# %%
plot_diffs('carpet_line1.jpg')

# %%
plot_diffs("line_2.jpg")

# %%
plot_diffs("line_3.jpg")
